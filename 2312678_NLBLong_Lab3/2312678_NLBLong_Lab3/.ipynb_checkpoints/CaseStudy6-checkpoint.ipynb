# %%
import pandas as pd
import seaborn as sns

# %%
dt = pd.read_csv('Udemy_Courses.csv', parse_dates=['published_timestamp'])

# %%
dt.dtypes
# Out:
# course_id                            int64
# course_title                           str
# is_paid                               bool
# price                                  str
# num_subscribers                      int64
# num_reviews                          int64
# num_lectures                         int64
# level                                  str
# content_duration                       str
# published_timestamp    datetime64[us, UTC]
# subject                                str
# dtype: object

# %%
dt.head(10)
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
# 2    1193886  #12 Hand Coordination: Let your Hands dance wi...     True
# 3    1116700  #4 Piano Hand Coordination: Fun Piano Runs in ...     True
# 4    1120410  #5  Piano Hand Coordination:  Piano Runs in 2 ...     True
# 5    1122832  #6 Piano Hand Coordination: Play Open 10 Balla...     True
# 6    1123184  #7 Piano Hand Coordination: Play Piano Runs in...     True
# 7     768028  * An Integrated Approach to the Fundamentals o...     True
# 8     206592  :::Beginners Guide To Creating Amazing Images ...     True
# 9     738910  [Value Investing] Where White People Keep Thei...     True
#
#   price  num_subscribers  num_reviews  num_lectures               level  \
# 0    35             3137           18            68          All Levels
# ...

# %%
dt.tail(5)
# Out:
#       course_id                                       course_title  is_paid  \
# 3677     328960  Your Own Site in 45 Min: The Complete Wordpres...     True
# 3678     552700    Your Second Course on Piano: Two Handed Playing     True
# 3679     631754  Zend Framework 2: Learn the PHP framework ZF2 ...     True
# 3680    1225194  Zoho Books Gestion Financière d'Entreprise pas...    False
# 3681     964478                Zombie Apocalypse Photoshop Actions     True
#
#      price  num_subscribers  num_reviews  num_lectures           level  \
# 3677   120             1566           29            36      All Levels
# 3678    70             1018           12            22  Beginner Level
# 3679    40              723          130            37      All Levels
# 3680  Free              229            0            33      All Levels
# 3681    50               12            1            15      All Levels
#
#      content_duration       published_timestamp              subject
# ...

# %%
dt.shape
print('Number of Rows', dt.shape[0])
print('Number of Columns', dt.shape[1])
# Out:
# Number of Rows 3682
# Number of Columns 11

# %%
dt.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3682 entries, 0 to 3681
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3682 non-null   int64
#  1   course_title         3682 non-null   str
#  2   is_paid              3682 non-null   bool
#  3   price                3682 non-null   str
#  4   num_subscribers      3682 non-null   int64
#  5   num_reviews          3682 non-null   int64
#  6   num_lectures         3682 non-null   int64
#  7   level                3682 non-null   str
#  8   content_duration     3682 non-null   str
#  9   published_timestamp  3682 non-null   datetime64[us, UTC]
#  10  subject              3682 non-null   str
# dtypes: bool(1), datetime64[us, UTC](1), int64(4), str(5)
# memory usage: 291.4 KB

# %%
dt.isnull().sum()
# Out:
# course_id              0
# course_title           0
# is_paid                0
# price                  0
# num_subscribers        0
# num_reviews            0
# num_lectures           0
# level                  0
# content_duration       0
# published_timestamp    0
# subject                0
# dtype: int64

# %%
sns.heatmap(dt.isnull())
# Out:
# <Axes: >

# %%
dup = dt.duplicated().any()
print('Are there any duplicated value?',dup)
# Out:
# Are there any duplicated value? True

# %%
dt=dt.drop_duplicates()

# %%
dup = dt.duplicated().any()
print('Are there any duplicated value?',dup)
# Out:
# Are there any duplicated value? False

# %%
dt.head(1)
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
#
#   price  num_subscribers  num_reviews  num_lectures       level  \
# 0    35             3137           18            68  All Levels
#
#   content_duration       published_timestamp              subject
# 0        1.5 hours 2014-09-18 05:07:05+00:00  Musical Instruments

# %%
dt['subject'].value_counts()
# Out:
# subject
# Web Development        1199
# Business Finance       1195
# Musical Instruments     680
# Graphic Design          602
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
sns.countplot(x= dt['subject'])
plt.xlabel("Subjects", fontsize=13)
plt.ylabel("Number of Courses Per Subject", fontsize=13)
plt.xticks(rotation=65)
plt.show()

# %%
dt.columns
# Out:
# Index(['course_id', 'course_title', 'is_paid', 'price', 'num_subscribers',
#        'num_reviews', 'num_lectures', 'level', 'content_duration',
#        'published_timestamp', 'subject'],
#       dtype='str')

# %%
dt['level'].value_counts()
# Out:
# level
# All Levels            1928
# Beginner Level        1269
# Intermediate Level     421
# Expert Level            58
# Name: count, dtype: int64

# %%
sns.countplot(x= dt['level'])
plt.xlabel("Level", fontsize=13)
plt.ylabel("Number of Courses Per Level", fontsize=13)
plt.xticks(rotation=65)
plt.show()

# %%
dt.columns
# Out:
# Index(['course_id', 'course_title', 'is_paid', 'price', 'num_subscribers',
#        'num_reviews', 'num_lectures', 'level', 'content_duration',
#        'published_timestamp', 'subject'],
#       dtype='str')

# %%
dt['is_paid'].value_counts()
# Out:
# is_paid
# True     3366
# False     310
# Name: count, dtype: int64

# %%
sns.countplot(x= dt['is_paid'])
plt.xlabel("Level", fontsize=13)
plt.ylabel("Number of Free & Paid Courses", fontsize=13)
plt.xticks(rotation=65)
plt.show()

# %%
dt.groupby(['is_paid']).mean(numeric_only=True)
# Out:
#              course_id  num_subscribers  num_reviews  num_lectures
# is_paid
# False    691446.970968     11533.951613   425.929032     21.416129
# True     675165.977718      2418.997623   131.364231     41.816993

# %%
dt.columns
# Out:
# Index(['course_id', 'course_title', 'is_paid', 'price', 'num_subscribers',
#        'num_reviews', 'num_lectures', 'level', 'content_duration',
#        'published_timestamp', 'subject'],
#       dtype='str')

# %%
sns.barplot(x="is_paid",y="num_subscribers",data=dt)
# Out:
# <Axes: xlabel='is_paid', ylabel='num_subscribers'>

# %%
dt.columns
# Out:
# Index(['course_id', 'course_title', 'is_paid', 'price', 'num_subscribers',
#        'num_reviews', 'num_lectures', 'level', 'content_duration',
#        'published_timestamp', 'subject'],
#       dtype='str')

# %%
sns.barplot(x="level",y="num_subscribers",data=dt)
plt.xticks(rotation=60)
plt.show()

# %%
dt.columns
# Out:
# Index(['course_id', 'course_title', 'is_paid', 'price', 'num_subscribers',
#        'num_reviews', 'num_lectures', 'level', 'content_duration',
#        'published_timestamp', 'subject'],
#       dtype='str')

# %%
dt[dt['num_subscribers'].max()==dt['num_subscribers']]['course_title']
# Out:
# 2230    Learn HTML5 Programming From Scratch
# Name: course_title, dtype: str

# %%
top_10=dt.sort_values(by="num_subscribers", ascending=False).head(10)

# %%
sns.barplot(x="num_subscribers", y="course_title", data=top_10)
# Out:
# <Axes: xlabel='num_subscribers', ylabel='course_title'>

# %%
dt.columns
# Out:
# Index(['course_id', 'course_title', 'is_paid', 'price', 'num_subscribers',
#        'num_reviews', 'num_lectures', 'level', 'content_duration',
#        'published_timestamp', 'subject'],
#       dtype='str')

# %%
plt.figure(figsize=(10,4))
sns.barplot(x='subject',y='num_reviews', data = dt)
# Out:
# <Axes: xlabel='subject', ylabel='num_reviews'>

# %%
plt.figure(figsize=(15,3))
sns.scatterplot(x="price",y="num_reviews", data=dt)
# Out:
# <Axes: xlabel='price', ylabel='num_reviews'>

# %%
dt.columns
# Out:
# Index(['course_id', 'course_title', 'is_paid', 'price', 'num_subscribers',
#        'num_reviews', 'num_lectures', 'level', 'content_duration',
#        'published_timestamp', 'subject'],
#       dtype='str')

# %%
len(dt[dt['course_title'].str.contains('python',case=False)])
# Out:
# 29

# %%
data_python = dt[dt['course_title'].str.contains('python',case=False)]
python = data_python.sort_values(by="num_subscribers",ascending=False).head(10)

# %%
sns.barplot(x='num_subscribers',y='course_title', data = python)
# Out:
# <Axes: xlabel='num_subscribers', ylabel='course_title'>

# %%
dt.columns
# Out:
# Index(['course_id', 'course_title', 'is_paid', 'price', 'num_subscribers',
#        'num_reviews', 'num_lectures', 'level', 'content_duration',
#        'published_timestamp', 'subject'],
#       dtype='str')

# %%
dt['Year']=dt['published_timestamp'].dt.year

# %%
dt.head(1)
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
#
#   price  num_subscribers  num_reviews  num_lectures       level  \
# 0    35             3137           18            68  All Levels
#
#   content_duration       published_timestamp              subject  Year
# 0        1.5 hours 2014-09-18 05:07:05+00:00  Musical Instruments  2014

# %%
sns.countplot(x='Year', data=dt)
# Out:
# <Axes: xlabel='Year', ylabel='count'>

# %%
dt.groupby('Year')['subject'].value_counts()
# Out:
# Year  subject
# 2011  Web Development          5
# 2012  Web Development         19
#       Musical Instruments     10
#       Graphic Design          10
#       Business Finance         6
# 2013  Business Finance        84
#       Web Development         56
#       Musical Instruments     39
#       Graphic Design          23
# 2014  Business Finance       192
#       Musical Instruments    120
#       Web Development        113
#       Graphic Design          66
# 2015  Business Finance       339
#       Web Development        336
#       Musical Instruments    171
#       Graphic Design         168
# 2016  Web Development        448
#       Business Finance       349
#       Musical Instruments    228
#       Graphic Design         181
# 2017  Business Finance       229
#       Web Development        223
#       Graphic Design         155
#       Musical Instruments    112
# Name: count, dtype: int64
